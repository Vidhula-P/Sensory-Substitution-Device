# %% [markdown]
# ### Sine table LUT

# %%
def LUT (address):
    if (address == 0): 
        return (int(2460658))
    elif (address == 1): 
        return (int(2762200))
    elif (address == 2): 
        return (int(2925946))
    elif (address == 3): 
        return (int(3284755))
    elif (address == 4): 
        return (int(686513))
    elif (address == 5): 
        return (int(3905735))
    elif (address == 6): 
        return (int(4384445))
    elif (address == 7): 
        return (int(4921316))
    elif (address == 8): 
        return (int(5524401))
    elif (address == 9): 
        return (int(5852787))
    elif (address == 10): 
        return (int(6569510))
    elif (address == 11): 
        return (int(7373921))
    elif (address == 12): 
        return (int(7812366))
    elif (address == 13): 
        return (int(8768891))
    elif (address == 14): 
        return (int(9842633))
    elif (address == 15): 
        return (int(11047908))
    elif (address == 16): 
        return (int(11704680))
    elif (address == 17): 
        return (int(13138126))
    elif (address == 18): 
        return (int(14746949))
    elif (address == 19): 
        return (int(15623838))
    elif (address == 20): 
        return (int(17537783))
    elif (address == 21): 
        return (int(19685266))
    elif (address == 22): 
        return (int(22095817))
    elif (address == 23): 
        return (int(23410256))
    elif (address == 24): 
        return (int(26276252))
    elif (address == 25): 
        return (int(29494793))
    elif (address == 26): 
        return (int31248571())
    elif (address == 27): 
        return (int(35075566))
    elif (address == 28): 
        return (int(39370533))
    elif (address == 29): 
        return (int(44191634))
    elif (address == 30): 
        return (int(46819617))
    elif (address == 31): 
        return (int(52553398))
    elif (address == 32): 
        return (int(58988691))
    elif (address == 33): 
        return (int(62497142))
    elif (address == 34): 
        return (int(70150237))
    elif (address == 35): 
        return (int(78741067))
    elif (address == 36): 
        return (int(88384163))
    elif (address == 37): 
        return (int(93639234))
    elif (address == 38): 
        return (int(105106797))
    elif (address == 39): 
        return (int(117978277))
    elif (address == 40): 
        return (int(124993390))
    elif (address == 41): 
        return (int(140300475))
    elif (address == 42): 
        return (int(157482134))
    elif (address == 43): 
        return (int(176767432))
    elif (address == 44): 
        return (int(187278469))
    elif (address == 45): 
        return (int(210213595))
    elif (address == 46): 
        return (int(235956555))
    elif (address == 47): 
        return (int(249987676))
    elif (address == 48): 
        return (int(280600950))
    elif (address == 49): 
        return (int(314964268))
    elif (address == 50): 
        return (int(353535759))
    elif (address == 51): 
        return (int(374557834))
    else:
        return(int(0))
